# %%
# !pip install "ibm-watsonx-ai==0.2.6"
# !pip install "langchain==0.1.16"
# !pip install "langchain-ibm==0.1.4"
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting ibm-watsonx-ai==0.2.6
#   Obtaining dependency information for ibm-watsonx-ai==0.2.6 from https://files.pythonhosted.org/packages/6f/b8/58371c362ff81203f34922a753a8fe9f564d0bf62dfc85630b49fa6361d7/ibm_watsonx_ai-0.2.6-py3-none-any.whl.metadata
#   Downloading ibm_watsonx_ai-0.2.6-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: ibm-watson-machine-learning>=1.0.349 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watsonx-ai==0.2.6) (1.0.367)
# Requirement already satisfied: requests in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (2.32.2)
# Requirement already satisfied: urllib3 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (2.3.0)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (2.1.4)
# Requirement already satisfied: certifi in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (2025.1.31)
# Requirement already satisfied: lomond in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (0.3.3)
# Requirement already satisfied: tabulate in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (0.9.0)
# Requirement already satisfied: packaging in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (24.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (2.13.6)
# Requirement already satisfied: importlib-metadata in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (8.6.1)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (2.9.0.post0)
# Requirement already satisfied: numpy<2,>=1.23.2 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from requests->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from requests->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (3.10)
# Requirement already satisfied: zipp>=3.20 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from importlib-metadata->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (3.21.0)
# Requirement already satisfied: six>=1.10.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from lomond->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai==0.2.6) (1.17.0)
# Downloading ibm_watsonx_ai-0.2.6-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.3 MB 960.0 kB/s eta 0:00:02
#    -- ------------------------------------- 0.1/1.3 MB 1.0 MB/s eta 0:00:02
#    -- ------------------------------------- 0.1/1.3 MB 1.0 MB/s eta 0:00:02
#    -- ------------------------------------- 0.1/1.3 MB 1.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.2/1.3 MB 702.7 kB/s eta 0:00:02
#    ----- ---------------------------------- 0.2/1.3 MB 654.4 kB/s eta 0:00:02
#    ------ --------------------------------- 0.2/1.3 MB 689.9 kB/s eta 0:00:02
#    ------ --------------------------------- 0.2/1.3 MB 689.9 kB/s eta 0:00:02
#    ---------- ----------------------------- 0.3/1.3 MB 805.1 kB/s eta 0:00:02
#    ---------- ----------------------------- 0.3/1.3 MB 744.3 kB/s eta 0:00:02
#    ----------- ---------------------------- 0.4/1.3 MB 781.2 kB/s eta 0:00:02
#    ----------- ---------------------------- 0.4/1.3 MB 781.2 kB/s eta 0:00:02
#    ----------- ---------------------------- 0.4/1.3 MB 781.2 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.6/1.3 MB 884.7 kB/s eta 0:00:01
#    ------------------- -------------------- 0.6/1.3 MB 907.9 kB/s eta 0:00:01
#    ------------------- -------------------- 0.6/1.3 MB 907.9 kB/s eta 0:00:01
#    ------------------- -------------------- 0.6/1.3 MB 907.9 kB/s eta 0:00:01
#    ------------------------ --------------- 0.8/1.3 MB 951.1 kB/s eta 0:00:01
#    ------------------------- -------------- 0.8/1.3 MB 964.5 kB/s eta 0:00:01
#    -------------------------- ------------- 0.9/1.3 MB 976.9 kB/s eta 0:00:01
#    -------------------------- ------------- 0.9/1.3 MB 976.9 kB/s eta 0:00:01
#    -------------------------- ------------- 0.9/1.3 MB 976.9 kB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.3 MB 962.5 kB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.3 MB 962.5 kB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.3 MB 962.5 kB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.3 MB 962.5 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.2/1.3 MB 928.6 kB/s eta 0:00:01
#    ---------------------------------------  1.3/1.3 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 995.8 kB/s eta 0:00:00
# Installing collected packages: ibm-watsonx-ai
#   Attempting uninstall: ibm-watsonx-ai
#     Found existing installation: ibm_watsonx_ai 1.2.9
#     Uninstalling ibm_watsonx_ai-1.2.9:
#       Successfully uninstalled ibm_watsonx_ai-1.2.9
# Successfully installed ibm-watsonx-ai-0.2.6
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting langchain==0.1.16
#   Obtaining dependency information for langchain==0.1.16 from https://files.pythonhosted.org/packages/ed/3e/93045d37eba24e0b5eb05312e30cd9e12805ea5f1ae9ba51ec8a7d2f5372/langchain-0.1.16-py3-none-any.whl.metadata
#   Downloading langchain-0.1.16-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: PyYAML>=5.3 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain==0.1.16) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain==0.1.16) (2.0.38)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain==0.1.16) (3.11.13)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain==0.1.16)
#   Obtaining dependency information for dataclasses-json<0.7,>=0.5.7 from https://files.pythonhosted.org/packages/c3/be/d0d44e092656fe7a06b55e6103cbce807cdbdee17884a5367c68c9860853/dataclasses_json-0.6.7-py3-none-any.whl.metadata
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain==0.1.16) (1.33)
# Collecting langchain-community<0.1,>=0.0.32 (from langchain==0.1.16)
#   Obtaining dependency information for langchain-community<0.1,>=0.0.32 from https://files.pythonhosted.org/packages/1b/d3/1f4d1941ae5a627299c8ea052847b99ad6674b97b699d8a08fc4faf25d3e/langchain_community-0.0.38-py3-none-any.whl.metadata
#   Downloading langchain_community-0.0.38-py3-none-any.whl.metadata (8.7 kB)
# Collecting langchain-core<0.2.0,>=0.1.42 (from langchain==0.1.16)
#   Obtaining dependency information for langchain-core<0.2.0,>=0.1.42 from https://files.pythonhosted.org/packages/6a/10/285fa149ce95300d91ea0bb124eec28889e5ebbcb59434d1fe2f31098d72/langchain_core-0.1.53-py3-none-any.whl.metadata
#   Downloading langchain_core-0.1.53-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain==0.1.16)
#   Obtaining dependency information for langchain-text-splitters<0.1,>=0.0.1 from https://files.pythonhosted.org/packages/68/6a/804fe5ca07129046a4cedc0697222ddde6156cd874c4c4ba29e4d271828a/langchain_text_splitters-0.0.2-py3-none-any.whl.metadata
#   Downloading langchain_text_splitters-0.0.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain==0.1.16)
#   Obtaining dependency information for langsmith<0.2.0,>=0.1.17 from https://files.pythonhosted.org/packages/de/f0/63b06b99b730b9954f8709f6f7d9b8d076fa0a973e472efe278089bde42b/langsmith-0.1.147-py3-none-any.whl.metadata
#   Downloading langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2,>=1 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain==0.1.16) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain==0.1.16) (2.10.6)
# Requirement already satisfied: requests<3,>=2 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain==0.1.16) (2.32.2)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain==0.1.16)
#   Obtaining dependency information for tenacity<9.0.0,>=8.1.0 from https://files.pythonhosted.org/packages/d2/3f/8ba87d9e287b9d385a02a7114ddcef61b26f86411e121c9003eb509a1773/tenacity-8.5.0-py3-none-any.whl.metadata
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.16) (1.18.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.16)
#   Obtaining dependency information for marshmallow<4.0.0,>=3.18.0 from https://files.pythonhosted.org/packages/34/75/51952c7b2d3873b44a0028b1bd26a25078c18f92f256608e8d1dc61b39fd/marshmallow-3.26.1-py3-none-any.whl.metadata
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.16)
#   Obtaining dependency information for typing-inspect<1,>=0.4.0 from https://files.pythonhosted.org/packages/65/f3/107a22063bf27bdccf2024833d3445f4eea42b2e598abfbd46f6a63b6cb0/typing_inspect-0.9.0-py3-none-any.whl.metadata
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonpointer>=1.9 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.16) (3.0.0)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.42->langchain==0.1.16)
#   Obtaining dependency information for packaging<24.0,>=23.2 from https://files.pythonhosted.org/packages/ec/1a/610693ac4ee14fcdf2d9bf3c493370e4f2ef7ae2e19217d7a237ff42367d/packaging-23.2-py3-none-any.whl.metadata
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.16) (0.28.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.16) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.16) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from pydantic<3,>=1->langchain==0.1.16) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from pydantic<3,>=1->langchain==0.1.16) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from pydantic<3,>=1->langchain==0.1.16) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from requests<3,>=2->langchain==0.1.16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from requests<3,>=2->langchain==0.1.16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from requests<3,>=2->langchain==0.1.16) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from requests<3,>=2->langchain==0.1.16) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.16) (3.1.1)
# Requirement already satisfied: anyio in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.16) (4.8.0)
# Requirement already satisfied: httpcore==1.* in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.16) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.16) (0.14.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.16)
#   Obtaining dependency information for mypy-extensions>=0.3.0 from https://files.pythonhosted.org/packages/2a/e2/5d3f6ada4297caebe1a2add3b126fe800c96f56dbe5d1988a2cbe0b267aa/mypy_extensions-1.0.0-py3-none-any.whl.metadata
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.16) (1.3.1)
# Downloading langchain-0.1.16-py3-none-any.whl (817 kB)
#    ---------------------------------------- 0.0/817.7 kB ? eta -:--:--
#    -- ------------------------------------- 41.0/817.7 kB 1.9 MB/s eta 0:00:01
#    ----- ---------------------------------- 102.4/817.7 kB 1.2 MB/s eta 0:00:01
#    ------- -------------------------------- 153.6/817.7 kB 1.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 204.8/817.7 kB 1.2 MB/s eta 0:00:01
#    ------------- -------------------------- 266.2/817.7 kB 1.2 MB/s eta 0:00:01
#    --------------- ------------------------ 317.4/817.7 kB 1.2 MB/s eta 0:00:01
#    ------------------ --------------------- 368.6/817.7 kB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 430.1/817.7 kB 1.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 481.3/817.7 kB 1.2 MB/s eta 0:00:01
#    -------------------------- ------------- 532.5/817.7 kB 1.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 593.9/817.7 kB 1.2 MB/s eta 0:00:01
#    ------------------------------- -------- 645.1/817.7 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 696.3/817.7 kB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 757.8/817.7 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 817.7/817.7 kB 1.2 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain_community-0.0.38-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.0 MB 1.4 MB/s eta 0:00:02
#    - -------------------------------------- 0.1/2.0 MB 1.1 MB/s eta 0:00:02
#    -- ------------------------------------- 0.1/2.0 MB 1.2 MB/s eta 0:00:02
#    --- ------------------------------------ 0.2/2.0 MB 1.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.2/2.0 MB 1.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.3/2.0 MB 1.1 MB/s eta 0:00:02
#    ------- -------------------------------- 0.4/2.0 MB 1.2 MB/s eta 0:00:02
#    -------- ------------------------------- 0.4/2.0 MB 1.2 MB/s eta 0:00:02
#    --------- ------------------------------ 0.5/2.0 MB 1.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.5/2.0 MB 1.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.6/2.0 MB 1.2 MB/s eta 0:00:02
#    ------------ --------------------------- 0.6/2.0 MB 1.2 MB/s eta 0:00:02
#    ------------- -------------------------- 0.7/2.0 MB 1.2 MB/s eta 0:00:02
#    -------------- ------------------------- 0.7/2.0 MB 1.2 MB/s eta 0:00:02
#    --------------- ------------------------ 0.8/2.0 MB 1.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 0.9/2.0 MB 1.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.9/2.0 MB 1.2 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.0 MB 1.2 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.0 MB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 1.1/2.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.1/2.0 MB 1.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.2/2.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------ --------------- 1.2/2.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.0 MB 1.2 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 1.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.4/2.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.4/2.0 MB 1.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.5/2.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 1.2 MB/s eta 0:00:01
#    -------------------------------- ------- 1.7/2.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.7/2.0 MB 1.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------ --- 1.8/2.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 1.9/2.0 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 1.9/2.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.2 MB/s eta 0:00:00
# Downloading langchain_core-0.1.53-py3-none-any.whl (303 kB)
#    ---------------------------------------- 0.0/303.1 kB ? eta -:--:--
#    ----- ---------------------------------- 41.0/303.1 kB 1.9 MB/s eta 0:00:01
#    ------------- -------------------------- 102.4/303.1 kB 1.2 MB/s eta 0:00:01
#    -------------------- ------------------- 153.6/303.1 kB 1.1 MB/s eta 0:00:01
#    --------------------------- ------------ 204.8/303.1 kB 1.2 MB/s eta 0:00:01
#    --------------------------------- ------ 256.0/303.1 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 303.1/303.1 kB 1.2 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.0.2-py3-none-any.whl (23 kB)
# Downloading langsmith-0.1.147-py3-none-any.whl (311 kB)
#    ---------------------------------------- 0.0/311.8 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/311.8 kB 991.0 kB/s eta 0:00:01
#    ----------- ---------------------------- 92.2/311.8 kB 1.1 MB/s eta 0:00:01
#    --------------------- ------------------ 163.8/311.8 kB 1.2 MB/s eta 0:00:01
#    -------------------------- ------------- 204.8/311.8 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 266.2/311.8 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 311.8/311.8 kB 1.2 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.9 kB ? eta -:--:--
#    ---------------------------------------- 50.9/50.9 kB 1.3 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ---------------------------------------- 0.0/53.0 kB ? eta -:--:--
#    ---------------------------------------- 53.0/53.0 kB 1.4 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: tenacity, packaging, mypy-extensions, typing-inspect, marshmallow, langsmith, dataclasses-json, langchain-core, langchain-text-splitters, langchain-community, langchain
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.3.11
#     Uninstalling langsmith-0.3.11:
#       Successfully uninstalled langsmith-0.3.11
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.40
#     Uninstalling langchain-core-0.3.40:
#       Successfully uninstalled langchain-core-0.3.40
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.6
#     Uninstalling langchain-text-splitters-0.3.6:
#       Successfully uninstalled langchain-text-splitters-0.3.6
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.19
#     Uninstalling langchain-0.3.19:
#       Successfully uninstalled langchain-0.3.19
# Successfully installed dataclasses-json-0.6.7 langchain-0.1.16 langchain-community-0.0.38 langchain-core-0.1.53 langchain-text-splitters-0.0.2 langsmith-0.1.147 marshmallow-3.26.1 mypy-extensions-1.0.0 packaging-23.2 tenacity-8.5.0 typing-inspect-0.9.0
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting langchain-ibm==0.1.4
#   Obtaining dependency information for langchain-ibm==0.1.4 from https://files.pythonhosted.org/packages/8b/fd/56afa51fad434919092b460131310ea5f4906302509b0461e70b932612dd/langchain_ibm-0.1.4-py3-none-any.whl.metadata
#   Downloading langchain_ibm-0.1.4-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: ibm-watsonx-ai<0.3.0,>=0.2.6 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain-ibm==0.1.4) (0.2.6)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.42 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain-ibm==0.1.4) (0.1.53)
# Requirement already satisfied: ibm-watson-machine-learning>=1.0.349 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (1.0.367)
# Requirement already satisfied: PyYAML>=5.3 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (0.1.147)
# Requirement already satisfied: packaging<24.0,>=23.2 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (2.10.6)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (8.5.0)
# Requirement already satisfied: requests in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (2.32.2)
# Requirement already satisfied: urllib3 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (2.3.0)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (2.1.4)
# Requirement already satisfied: certifi in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (2025.1.31)
# Requirement already satisfied: lomond in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (0.3.3)
# Requirement already satisfied: tabulate in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (0.9.0)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (2.13.6)
# Requirement already satisfied: importlib-metadata in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (8.6.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (0.28.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (4.12.2)
# Requirement already satisfied: anyio in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (4.8.0)
# Requirement already satisfied: httpcore==1.* in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (1.0.7)
# Requirement already satisfied: idna in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (0.14.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from ibm-cos-sdk-core==2.13.6->ibm-cos-sdk<2.14.0,>=2.12.0->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (2.9.0.post0)
# Requirement already satisfied: numpy<2,>=1.23.2 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from pandas<2.2.0,>=0.24.2->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from requests->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (3.4.1)
# Requirement already satisfied: zipp>=3.20 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from importlib-metadata->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (3.21.0)
# Requirement already satisfied: six>=1.10.0 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from lomond->ibm-watson-machine-learning>=1.0.349->ibm-watsonx-ai<0.3.0,>=0.2.6->langchain-ibm==0.1.4) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in d:\python\projects\ctxenginprompttempllangchain\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.42->langchain-ibm==0.1.4) (1.3.1)
# Downloading langchain_ibm-0.1.4-py3-none-any.whl (9.8 kB)
# Installing collected packages: langchain-ibm
# Successfully installed langchain-ibm-0.1.4
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

from ibm_watsonx_ai.foundation_models import Model
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
from ibm_watson_machine_learning.foundation_models.extensions.langchain import WatsonxLLM
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File D:\python\projects\CtxEnginPromptTemplLangChain\.venv\Lib\site-packages\langchain\_api\module_import.py:69, in create_importer.<locals>.import_by_name(name)
#      68 try:
# ---> 69     module = importlib.import_module(new_module)
#      70 except ModuleNotFoundError as e:
#
# File C:\Program Files\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'langchain_community'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File D:\python\projects\CtxEnginPromptTemplLangChain\.venv\Lib\site-packages\ibm_watson_machine_learning\foundation_models\extensions\langchain\llm.py:10
#       9     from langchain.llms.base import LLM
# ---> 10     from langchain.llms.utils import enforce_stop_tokens
#      11 except ImportError:
#
# File D:\python\projects\CtxEnginPromptTemplLangChain\.venv\Lib\site-packages\langchain\llms\utils.py:18, in __getattr__(name)
#      17 """Look up attributes dynamically."""
# ---> 18 return _import_attribute(name)
#
# File D:\python\projects\CtxEnginPromptTemplLangChain\.venv\Lib\site-packages\langchain\_api\module_import.py:72, in create_importer.<locals>.import_by_name(name)
#      71 if new_module.startswith("langchain_community"):
# ---> 72     raise ModuleNotFoundError(
#      73         f"Module {new_module} not found. "
#      74         "Please install langchain-community to access this module. "
#      75         "You can install it using `pip install -U langchain-community`"
#      76     ) from e
#      77 raise
#
# ModuleNotFoundError: Module langchain_community.llms.utils not found. Please install langchain-community to access this module. You can install it using `pip install -U langchain-community`
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 11
#       9 from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
#      10 from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
# ---> 11 from ibm_watson_machine_learning.foundation_models.extensions.langchain import WatsonxLLM
#      12 from langchain_core.prompts import PromptTemplate
#      13 from langchain.chains import LLMChain
#
# File D:\python\projects\CtxEnginPromptTemplLangChain\.venv\Lib\site-packages\ibm_watson_machine_learning\foundation_models\extensions\langchain\__init__.py:6
#       1 #  -----------------------------------------------------------------------------------------
#       2 #  (C) Copyright IBM Corp. 2023-2024.
#       3 #  https://opensource.org/licenses/BSD-3-Clause
#       4 #  -----------------------------------------------------------------------------------------
# ----> 6 from .llm import WatsonxLLM
#
# File D:\python\projects\CtxEnginPromptTemplLangChain\.venv\Lib\site-packages\ibm_watson_machine_learning\foundation_models\extensions\langchain\llm.py:12
#      10     from langchain.llms.utils import enforce_stop_tokens
#      11 except ImportError:
# ---> 12     raise ImportError("Could not import langchain: Please install langchain extension.")
#      13 from ibm_watson_machine_learning.foundation_models import Model, ModelInference
#      14 from ibm_watson_machine_learning.foundation_models.utils.utils import _raise_watsonxllm_deprecation_warning
#
# ImportError: Could not import langchain: Please install langchain extension.
